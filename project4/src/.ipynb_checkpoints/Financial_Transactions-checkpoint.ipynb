# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.mlab as mlab
import math as m
import numpy as np
import random
import copy

# %%
def makeagents(N, money):
    agents = np.zeros(N)
    for i in range(len(agents)):
        agents[i] = money
    return agents

# %%
def transactions(agent_array, tr_num):
    people = copy.copy(agent_array)
    total_money_begin = sum(agent_array)
    current = 0
    while current <= tr_num:
        i = random.randint(0,len(agent_array)-1)
        j = random.randint(0,len(agent_array)-1)
        m_i = people[i]
        m_j = people[j]
        total_m = m_i + m_j
        epsilon = random.uniform(0,1)
        if people[i]>0 and people[j]>0:
            people[i] = epsilon*total_m
            people[j] = (1-epsilon)*total_m
        else:
            continue
        current += 1
    total_money_end = sum(people)
    #print(total_money_begin, total_money_end)
    
    return people

# %%
def avg_money(array):
    length = len(array)
    average = 0
    for i in array:
        average += i/length
    return round(average,2)

# %%
def avg_money_sq(array):
    length = len(array)
    average = 0
    for i in array:
        average += i**2/length
    return round(average,2)

def variance(array):
    return (avg_money_sq(array)-(avg_money(array))**2)**(1/2)

# %%
trial_1 = transactions(makeagents(1000,1500),2000)
plt.hist(trial_1,bins=100)
avg_money(trial_1)
# Out:
# 1499.4400000000001

# %%
trial_2 = transactions(makeagents(500,10000),1000000)
plt.hist(trial_2 ,bins=100)
avg_money(trial_2)
# Out:
# 10368.780000000001

# %%
trial_3 = transactions(makeagents(500,420),1000000)
plt.hist(trial_3 ,bins=100)
avg_money(trial_3)
# Out:
# 464.47000000000003

# %%
def distribution_exp(array):
    avg = avg_money(array)
    beta = 1/avg
    mon = np.linspace(0,max(array))
    wn = []
    for i in mon:
        wn.append(beta*m.exp(-beta*i))
    h = plt.plot(mon, wn, lw=2)
    
    plt.xlabel("Amount of Money that The Individual Possesses")
    plt.ylabel("Wealth (1/Money)")
    plt.title("Distribution of Wealth")
    
    plt.show()

# %%
distribution_exp(trial_1)

# %%
def distribution_log(array):
    avg = avg_money(array)
    beta = 1/avg
    mon = np.linspace(0,max(array))
    wn = []
    for i in mon:
        wn.append(m.log(beta*m.exp(-beta*i)))
    h = plt.plot(mon, wn, lw=2)
    
    plt.xlabel("Amount of Money that The Individual Possesses")
    plt.ylabel("Log of Wealth (1/Money)")
    plt.title("Distribution of Wealth")
    
    plt.show()

# %%
distribution_log(trial_1)

# %%
def overlay_exp(array):
    avg = avg_money(array)
    beta = 1/avg
    
    fig = plt.figure(figsize=(5,5))
    ax  = fig.add_subplot(111)
    
    # now plot
    data= array
    counts, bins, bars = ax.hist(data, bins=100)
    mon = np.linspace(0,max(array))
    wn = []
    for i in mon:
        wn.append(max(counts)*m.exp(-beta*i))
    h = ax.plot(mon, wn, lw=2, color='r')
    
    #Nice-ness
    plt.xlabel("Amount of Money that The Individual Possesses")
    plt.ylabel("Counts of Histogram")
    plt.title("Distribution of Wealth")
    
    # show
    plt.show()

# %%
overlay_exp(trial_1)

# %%
overlay_exp(trial_2)

# %%
overlay_exp(trial_3)

# %%
def trans_save(agent_array, tr_num, lmbda):
    people = copy.copy(agent_array)
    #total_money_begin = sum(agent_array)
    current = 0
    while current <= tr_num:
        i = random.randint(0,len(agent_array)-1)
        j = random.randint(0,len(agent_array)-1)
        m_i = people[i]
        m_j = people[j]
        total_m = m_i + m_j
        epsilon = random.uniform(0,1)
        if people[i]>0 and people[j]>0:
            dm = (1-lmbda)*(epsilon*m_j-(1-epsilon)*m_i)
            people[i] = m_i+dm
            people[j] = m_j-dm
        else:
            continue
        current += 1
    #total_money_end = sum(people)
    #print(total_money_begin, total_money_end)
    
    return people

# %%
trial_4 = trans_save(makeagents(500,420),1000000, 0.25)
plt.hist(trial_4, bins=100)
plt.xlabel("Amount of Money that The Individual Possesses")
plt.ylabel("Counts of Histogram")
plt.title("Distribution of Wealth")

# %%
trial_5 = trans_save(makeagents(500,420),1000000, 0.5)
plt.hist(trial_5, bins=100)
plt.xlabel("Amount of Money that The Individual Possesses")
plt.ylabel("Counts of Histogram")
plt.title("Distribution of Wealth")

# %%
trial_6 = trans_save(makeagents(500,420),1000000, 0.9)
plt.hist(trial_6, bins=100)
plt.xlabel("Amount of Money that The Individual Possesses")
plt.ylabel("Counts of Histogram")
plt.title("Distribution of Wealth")

# %%
def overlay_gauss(array):
    avg = avg_money(array)
    sigma = variance(array)
    
    fig = plt.figure(figsize=(5,5))
    ax  = fig.add_subplot(111)
    
    # now plot
    data= array
    counts, bins, bars = ax.hist(data, bins=100, normed=True)
    mon = np.linspace(0,max(array))
    h = ax.plot(mon, mlab.normpdf(mon, avg, sigma), lw=2, color='r')
    
    #Nice-ness
    plt.xlabel("Amount of Money that The Individual Possesses")
    plt.ylabel("Counts of Histogram")
    plt.title("Distribution of Wealth")
    
    # show
    plt.show()

# %%
avg_money(trial_4)
# Out:
# 419.13

# %%
avg_money_sq(trial_4)
# Out:
# 264478.13

# %%
variance(trial_4)
# Out:
# 298.00700176338142

# %%
 overlay_gauss(trial_4)

# %%
 overlay_gauss(trial_5)

# %%
 overlay_gauss(trial_6)

# %%
def agents_diff(N, money):
    agents = np.zeros(N)
    for i in range(len(agents)):
        agents[i] = random.randint(0,money)
    return agents

def tr_nearest(agent_array, tr_num,user_set,a):
    people = copy.copy(agent_array)
    current = 0
    while current <= tr_num:
        i,j = random.sample(range(0, len(agent_array)-1),2)
        #print(i,j)
        m_i = people[i]
        m_j = people[j]
        #print(m_i,m_j)
        total_m = m_i + m_j
        diff = m_i-m_j
        if diff==0:
            continue
        abs_diff = abs(diff)
        prob = abs_diff**(-a)
        #print(prob)
        if prob>=user_set:
            epsilon = random.uniform(0,1)
            if people[i]>0 and people[j]>0:
                people[i] = epsilon*total_m
                people[j] = (1-epsilon)*total_m
            else:
                continue
        else:
            continue
        current += 1
    #print(total_money_begin, total_money_end)
    
    return people

# %%
trial_7 = tr_nearest(agents_diff(500,420),1000,0.7, 0.5)
trial_8 = tr_nearest(agents_diff(500,420),1000,0.7, 1.0)
trial_9 = tr_nearest(agents_diff(500,420),1000,0.7, 1.5)
trial_10 = tr_nearest(agents_diff(500,420),1000,0.7, 2.0)
#trial_11 = tr_nearest(agents_diff(500,420),1000,0.7, 0)
plt.hist(trial_7, bins=100, label='alpha=0.5')
plt.hist(trial_8, bins=100, label='alpha=1.0')
plt.hist(trial_9, bins=100, label='alpha=1.5')
plt.hist(trial_10, bins=100, label='alpha=2.0')
#plt.hist(trial_11, bins=100, label='alpha=0')
plt.legend(loc="upper right")

# %%
def tr_nearest_save(agent_array, tr_num,user_set,lmbda, a):
    people = copy.copy(agent_array)
    current = 0
    while current <= tr_num:
        i,j = random.sample(range(0, len(agent_array)-1),2)
        #print(i,j)
        m_i = people[i]
        m_j = people[j]
        #print(m_i,m_j)
        total_m = m_i + m_j
        diff = m_i-m_j
        if diff==0:
            continue
        abs_diff = abs(diff)
        prob = abs_diff**(-a)
        #print(prob)
        if prob>=user_set:
            epsilon = random.uniform(0,1)
            if people[i]>0 and people[j]>0:
                dm = (1-lmbda)*(epsilon*m_j-(1-epsilon)*m_i)
                people[i] = m_i+dm
                people[j] = m_j-dm
            else:
                continue
        else:
            continue
        current += 1
    #print(total_money_begin, total_money_end)
    
    return people

# %%
trial_12 = tr_nearest_save(agents_diff(500,420),1000,0.7,0.5,0.5)
trial_13 = tr_nearest_save(agents_diff(500,420),1000,0.7,0.5,1.0)
trial_14 = tr_nearest_save(agents_diff(500,420),1000,0.7,0.5,1.5)
trial_15 = tr_nearest_save(agents_diff(500,420),1000,0.7,0.5,2.0)
# Out:
# (array([ 132.,   94.,   78.,   49.,   54.,   43.,   23.,   14.,   11.,    2.]),
#  array([   0.        ,   74.3795317 ,  148.75906341,  223.13859511,
#          297.51812682,  371.89765852,  446.27719022,  520.65672193,
#          595.03625363,  669.41578534,  743.79531704]),
#  <a list of 10 Patch objects>)
